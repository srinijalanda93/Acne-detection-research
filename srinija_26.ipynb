# %% [markdown]
# <a href="https://colab.research.google.com/github/srinijalanda93/Acne-detection-research/blob/main/srinija_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbformat

# Load notebook
path = "srinija_26_lab1.ipynb"
nb = nbformat.read(path, as_version=4)

# Clean widgets metadata
if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

# Save cleaned notebook
with open("cleaned_notebook.ipynb", "w") as f:
    nbformat.write(nb, f)

print("Cleaned notebook saved as 'cleaned_notebook.ipynb'")
